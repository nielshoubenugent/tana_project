# %%
#imports
import h5py
import numpy as np
import matplotlib.pyplot as plt
from astropy import units
import getdata
from scipy.optimize import curve_fit

from galpy.potential import TwoPowerSphericalPotential
from galpy.potential import HernquistPotential
from galpy.potential import PlummerPotential
from galpy.potential import DehnenSphericalPotential
from galpy.potential import DehnenCoreSphericalPotential
from galpy.potential import JaffePotential
from galpy.potential import NFWPotential
from galpy.potential import PowerSphericalPotential
from galpy.potential import PowerSphericalPotentialwCutoff
from galpy.potential import PseudoIsothermalPotential

# %% [markdown]
# First, the density profile is computed.

# %%
def getdensityprofile(nr_bins = 100, bin_distr = "adaptive", r_lowercutoff= 5.0*units.kpc, r_uppercutoff=50.0*units.kpc):
    bin_distr_options = ["linear", "logarithmic", "adaptive"]
    coords = getdata.coordskpc()
    mass = getdata.masssolar()
    
    if(bin_distr not in bin_distr_options):
        print(f"Error: bin_distr contains no valid distribution type. Choose from: " + str(bin_distr_options) + ", performing linear distribution instead.")
        bin_distr = "linear"

    if((nr_bins <= 1) or (isinstance(nr_bins, int) == False)):
        print(f"Error: bin amount must be a positive integer. Will now default to 1000 bins.")
        nr_bins = 1000

    if(r_uppercutoff <= 1.0*units.kpc):
        print(f"Error: cutoff radius must be large enough to contain data. Setting it to 50 kpc.")
        r_uppercutoff = 50.0*units.kpc
        
    if(r_lowercutoff >= r_uppercutoff):
        print(f"Error: lower cutoff radius must be smaller than upper cutoff radius. Using default values instead.")
        r_lowercutoff = 5.0*units.kpc
        r_uppercutoff = 50.0*units.kpc

    if(r_lowercutoff >= 70.0*units.kpc):
        print(f"Error: lower cutoff radius is too large, not encapsulating meaningful data. Using default values instead.")
        r_lowercutoff = 5.0*units.kpc
    
    coord_com = np.sum(coords,axis=0) / len(coords)
    coords_centred = coords - coord_com
    com_dist = np.sqrt(np.sum(coords_centred**2, axis=1))
    #remove uncertain regions from COM. lowercutoff because of large std in bins, see scatterplot.
    com_dist = com_dist[com_dist<=r_uppercutoff] 
    com_dist = com_dist[com_dist>=r_lowercutoff]
    
    r_min = np.min(com_dist)
    r_max = np.max(com_dist)
    bins = np.linspace(r_min, r_max, nr_bins) 
    
    if(bin_distr == "adaptive"):
        com_dist_sorted = np.sort(com_dist)
        nr_particles = len(com_dist_sorted)

        bin_size = nr_particles // nr_bins
        bin_limit = nr_bins*bin_size
        bins = com_dist_sorted[:bin_limit].reshape(nr_bins, bin_size)

        bin_inner_bound = bins[:, 0]         
        bin_outer_bound = bins[:, -1]       
        bin_centre = np.mean(bins, axis=1)  

        bin_volume = (4/3)*np.pi*(bin_outer_bound**3 - bin_inner_bound**3)
        bin_density = bin_size*mass / bin_volume
        bin_poisson_error = np.sqrt(bin_size)*mass / bin_volume
        bin_std = np.std(bins, axis=1)
        return bin_centre, bin_density, bin_poisson_error, bin_std
        
    if(bin_distr == "linear"):
        bins = np.linspace(r_min, r_max, nr_bins)
    if(bin_distr == "logarithmic"):
        bins = np.logspace(np.log10(r_min.value), np.log10(r_max.value), nr_bins) * r_min.unit
    
    bin_counts, bin_edges = np.histogram(com_dist, bins=bins)
    bin_inner_bound = bin_edges[:-1]
    bin_outer_bound = bin_edges[1:]
    bin_centre = (bin_outer_bound + bin_inner_bound) / 2
    
    bin_volume = (4/3)*np.pi*(bin_outer_bound**3 - bin_inner_bound**3)
    bin_density = bin_counts*mass / bin_volume 
    bin_poisson_error = bin_density / np.sqrt(bin_counts) 

    #remove zero density points to avoid logarithmic errors and fit errors
    nonzero_indices = [i for i, density in enumerate(bin_density) if density > 0.0]

    bin_density = [bin_density[i] for i in nonzero_indices] * bin_density.unit
    bin_centre = [bin_centre[i] for i in nonzero_indices] * bin_centre.unit
    bin_poisson_error = [bin_poisson_error[i] for i in nonzero_indices] * bin_poisson_error.unit

    return bin_centre, bin_density, bin_poisson_error

# %%
def plotdensityfunction(nr_bins = 1000, bin_distr = "adaptive", plot_scale = "logarithmic", r_lowercutoff=0.0*units.kpc, r_uppercutoff=1000.0*units.kpc, title="Title", savefig = False, save_name="Density_scatter"):
    bin_centre, bin_density, bin_poisson_error, bin_std = getdensityprofile(nr_bins=nr_bins, bin_distr=bin_distr, r_lowercutoff=r_lowercutoff, r_uppercutoff=r_uppercutoff)

    plot_scale_options = ["linear", "logarithmic", "both", "loglog"]
    if(plot_scale not in plot_scale_options):
        print(f"Error: wrong scaling option entered. Choose from the following: " + str(plot_scale_options) + str("/nplotting in logarithmic scale instead."))
        plot_scale = "logarithmic"

    fig = plt.figure(figsize=(10,10), dpi=200)
    plt.xlabel("Radius (" + str(bin_centre.unit) + ")")
    plt.ylabel("Density (" + str(bin_density.unit) + ")")
    plt.title(title)
    if((plot_scale == "linear") or (plot_scale == "logarithmic")):
        plt.scatter(bin_centre, bin_density, s=1)
        plt.errorbar(bin_centre, bin_density, yerr=bin_poisson_error, capsize=1, fmt='none', alpha=0.0)

        if(plot_scale == "logarithmic"):
            plt.xscale("log")
            plt.yscale("log")
        if(plot_scale == "linear"):
            plt.xscale("linear")
            plt.yscale("linear")
        plt.show()

    if(plot_scale == "both"):
        plt.subplot(2, 1, 1)
        plt.scatter(bin_centre, bin_density, s=1)
        plt.errorbar(bin_centre, bin_density, yerr=bin_poisson_error, capsize=1, fmt='none', alpha=0.0)
        plt.xscale("log")
        plt.yscale("log")
        
        plt.subplot(2, 1, 2)
        plt.scatter(bin_centre, bin_density, s=1)
        plt.errorbar(bin_centre, bin_density, yerr=bin_poisson_error, capsize=1, fmt='none', alpha=0.0)
        plt.xscale("linear")
        plt.yscale("linear")
        plt.show()

    if(plot_scale == "loglog"):
        bin_centrelog = np.log10(bin_centre.value)*bin_centre.unit
        bin_densitylog = np.log10(bin_density.value)*bin_density.unit
        bin_stdlog = bin_std
        bin_poisson_errorlog = np.log10(bin_poisson_error.value)*bin_poisson_error.unit

        plt.scatter(bin_centre, bin_density, s=2, label="Data")
        plt.errorbar(bin_centre, bin_density, xerr=bin_stdlog, capsize=5, fmt='none', alpha=0.5, c="red", label="Bin STD")
        plt.xscale("log")
        plt.yscale("log")
        plt.legend()

        if (savefig):
            plt.savefig(save_name)
        plt.show()

# %% [markdown]
# The following shows an analysis of the calculated density profile. The bins below 3kpc and above 50kpc show a large positional std. Furthermore, above 50kpc is very sparsely populated with a very low relative density. Therefore, particles below 3kpc and above 50kpc will be removed to increase positional accuracy.

# %%
plotdensityfunction(nr_bins = 100, bin_distr = "adaptive", plot_scale = "logarithmic", title="Density profile of all particles")

# %%
plotdensityfunction(nr_bins = 50, bin_distr = "adaptive", plot_scale = "loglog", title="Density profile with positional uncertainty", savefig=True, save_name="density_profile_pos_uncertainty")

# %%
plotdensityfunction(nr_bins = 50, bin_distr = "adaptive", plot_scale = "loglog", r_lowercutoff=5.0*units.kpc, r_uppercutoff=50.0*units.kpc, title="Density profile after filtering", savefig=True, save_name="density_filtered")

# %% [markdown]
# Then, several spherically symmetric potentials are computed and later compared. The fits are done in logspace, in order to avoid the imbalanced weighting of the largest densities (several orders of magnitudes larger than most points). Adaptive binning is done, where each point encapsulates the same number of points. This causes the best known regions to be weighted more strongly by providing more points there.

# %%
def calcpotentialdensity(bin_radius, potential_name, inputislog, *params):
    r_kpc = bin_radius
    if (inputislog == True):
        r_kpc = 10**bin_radius
    
    r_kpc = r_kpc * units.kpc

    #first 2 parameters are always mass and length scales
    total_mass =  (getdata.masssolar() * len(getdata.coordskpc())) 
    mscale = total_mass
    lscale = params[0] * units.kpc

    #make potential name lowercase, otherwise casesensitive
    potential_name = potential_name.lower()
    
    if (potential_name == "doublepowerlaw"):
        potential = TwoPowerSphericalPotential(amp=mscale, a=lscale, alpha=params[1], beta=params[2])
    elif (potential_name == "hernquist"):
        potential = HernquistPotential(amp=mscale, a=lscale)
    elif (potential_name == "plummer"):
        potential = PlummerPotential(amp=mscale, b=lscale)
    elif (potential_name == "dehnenspherical"):
        potential = DehnenSphericalPotential(amp=mscale, a=lscale, alpha=params[1])
    elif (potential_name == "dehnencorespherical"):
        potential = DehnenCoreSphericalPotential(amp=mscale, a=lscale)
    elif (potential_name == "jaffe"):
        potential = JaffePotential(amp=mscale, a=lscale)
    elif (potential_name == "nfw"):
        potential = NFWPotential(amp=mscale, a=lscale)
    elif (potential_name == "powerspherical"):
        potential = PowerSphericalPotential(amp=mscale, alpha=params[1], normalize=False, r1=lscale)
    elif (potential_name == "powersphericalwcutoff"):
        potential = PowerSphericalPotentialwCutoff(amp=params[1]*(units.Msun / units.kpc**3), alpha=params[2], rc=params[3]*units.kpc, normalize=False, r1=lscale)
    elif (potential_name == "pseudoisothermal"):
        potential = PseudoIsothermalPotential(amp=mscale, a=lscale)
    else:
        raise ValueError(f"Unknown potential: {potential_name}")

    density = potential.dens(r_kpc, z=0*units.kpc, phi=0, t=0, forcepoisson=False).to("solMass/kpc3")
    if (inputislog == True):
        return np.log10(density.value)
    else:
        return density.value

# %%
def show_fitparameters_errors(param, bdensity, fitdensity, potentialname):
    bindensity_log = np.log10(bdensity)
    fitdensity_log = np.log10(fitdensity)
    
    residuals = bindensity_log - fitdensity_log         
    rms_error = np.sqrt(np.mean(residuals**2))                          
    
    squaresum_residual = np.sum(residuals**2)
    squaresum_total = np.sum((bindensity_log - np.mean(bindensity_log))**2)
    rsquared_error = 1.0 - (squaresum_residual / squaresum_total)            #relative error

    print("RMSE of " + potentialname + " fit: " + str(rms_error))
    print("RSQUARED of " + potentialname + " fit: " + str(rsquared_error))   #RSQUARED of 1 is best.

# %%
def getbestfit(nr_bins=80, bin_distr="adaptive", potential_name="doublepowerlaw"):
    bin_radius, bin_density, bin_poisson_error, bin_std = getdensityprofile(nr_bins=nr_bins, bin_distr=bin_distr)
    potential_name = potential_name.lower()

    # Log-space setup
    bin_radius_log = np.log10(bin_radius.value)
    bin_density_log = np.log10(bin_density.value)
    inputislog = True

    # Initial parameter guesses
    
    bin_radius_average = sum(bin_radius) / len(bin_radius)
    total_mass =  (getdata.masssolar() * len(getdata.coordskpc())) 
    params = [bin_radius_average.value]

    # Add extra parameters if needed
    if (potential_name == "doublepowerlaw"):
        #alpha, beta
        params += [1.5, 3.5]
    if (potential_name == "dehnenspherical"):
        #alpha
        params += [1.5]
    if (potential_name == "powerspherical"):
        #alpha
        params += [1.5]
    if (potential_name == "powersphericalwcutoff"):
        #density, alpha, rcuttoff
        params += [15.0, 1.5, 10.0]
    
    total_mass =  (getdata.masssolar() * len(getdata.coordskpc())) 
    
    # black magic function to avoid scipy.logfit error (expects r_log as first input)
    def model_for_fit(r_log, *fit_params):
        return calcpotentialdensity(r_log, potential_name, inputislog, *fit_params)
        
    #loglog fit
    popt, pcov = curve_fit(model_for_fit, bin_radius_log, bin_density_log, p0=params)

    params = list(popt)
    print("optimal parameters for " + potential_name + " with mass " + str(total_mass.to("GsolMass")) + ", lengthscale: " + str(params[0]*units.kpc) + ", and other parameters: " + str(params[1:]))
    return params

# %%
def plotpotentialdensityfit(nr_bins = 40, bin_distr = "adaptive", potential_name = "doublepowerlaw", savefig=False, save_name="Density_fit"):
    bin_radius, bin_density, bin_poisson_error, bin_std = getdensityprofile(nr_bins=nr_bins, bin_distr=bin_distr)
    fit_parameters = getbestfit(nr_bins=nr_bins, bin_distr=bin_distr, potential_name=potential_name)
    inputislog = False
    
    fit_density = (calcpotentialdensity(bin_radius.value, potential_name, inputislog, *fit_parameters)) * units.Msun / (units.kpc**3)
    show_fitparameters_errors(fit_parameters, bin_density.value, fit_density.value, potential_name)

    fig = plt.figure(figsize=(10,10), dpi=200)
    fig, axs = plt.subplots(2, sharex=False, sharey=False)

    axs[0].scatter(bin_radius, bin_density, s=1, label="data")
    axs[0].plot(bin_radius, fit_density, c="red", label="galpy fit")
    axs[0].set_xscale("log")
    axs[0].set_yscale("log")
        
    axs[1].scatter(bin_radius, bin_density, s=1, label="data")
    axs[1].plot(bin_radius, fit_density, c="red", label="galpy fit")
    axs[1].set_xscale("linear")
    axs[1].set_yscale("linear")
    
    fig.supxlabel("Radius (" + str(bin_radius.unit) + ")") 
    fig.supylabel("Density (" + str(bin_density.unit) + ")") 
        
    plt.suptitle("Best fit of " + potential_name)
    plt.legend()
    plt.tight_layout()
    if (savefig):
        plt.savefig(save_name)
    plt.show()

# %%
#Fits very well for small lengthscales, but overestimates density at larger scales.
plotpotentialdensityfit(nr_bins = 100, bin_distr = "adaptive", potential_name = "doublepowerlaw", savefig=True, save_name="density_double_power")
# Out:
# optimal parameters for doublepowerlaw with mass 161.47893455855902 GsolMass, lengthscale: 10.344022339239432 kpc, and other parameters: [np.float64(0.9317509186810822), np.float64(3.0860645888204052)]
# RMSE of doublepowerlaw fit: 0.01768855611354272
# RSQUARED of doublepowerlaw fit: 0.9991089932927784

# %%
#fundamentally follows the same behaviour as the data This seems to be the best potential for all lengthscales.
plotpotentialdensityfit(nr_bins = 100, bin_distr = "adaptive", potential_name = "powersphericalwcutoff")
# Out:
# C:\Users\niels\anaconda3\envs\tana2025\Lib\site-packages\galpy\potential\PowerSphericalPotentialwCutoff.py:62: RuntimeWarning: invalid value encountered in scalar power
#   self._amp *= r1**self.alpha
#
# C:\Users\niels\anaconda3\envs\tana2025\Lib\site-packages\galpy\potential\PowerSphericalPotentialwCutoff.py:62: RuntimeWarning: invalid value encountered in scalar power
#   self._amp *= r1**self.alpha
#
# C:\Users\niels\anaconda3\envs\tana2025\Lib\site-packages\galpy\potential\PowerSphericalPotentialwCutoff.py:62: RuntimeWarning: invalid value encountered in scalar power
#   self._amp *= r1**self.alpha
#
# C:\Users\niels\anaconda3\envs\tana2025\Lib\site-packages\galpy\potential\PowerSphericalPotentialwCutoff.py:62: RuntimeWarning: invalid value encountered in scalar power
#   self._amp *= r1**self.alpha
#
# C:\Users\niels\anaconda3\envs\tana2025\Lib\site-packages\galpy\potential\PowerSphericalPotentialwCutoff.py:62: RuntimeWarning: invalid value encountered in scalar power
#   self._amp *= r1**self.alpha
#
# optimal parameters for powersphericalwcutoff with mass 161.47893455855902 GsolMass, lengthscale: 709.7947609616324 kpc, and other parameters: [np.float64(582.2033149209119), np.float64(1.9867058816481253), np.float64(57.901097454017076)]
# RMSE of powersphericalwcutoff fit: 0.01323666830703313
# RSQUARED of powersphericalwcutoff fit: 0.9995010539620369

# %%
#underperforms if mass-scale is untouched
plotpotentialdensityfit(nr_bins = 100, bin_distr = "adaptive", potential_name = "hernquist")
# Out:
# C:\Users\niels\AppData\Local\Temp\ipykernel_15096\743650313.py:41: RuntimeWarning: invalid value encountered in log10
#   return np.log10(density.value)
#
# optimal parameters for hernquist with mass 161.47893455855902 GsolMass, lengthscale: 12.162221750082885 kpc, and other parameters: []
# RMSE of hernquist fit: 0.4698298835774094
# RSQUARED of hernquist fit: 0.3713955092025757

# %%
#generally bad
plotpotentialdensityfit(nr_bins = 100, bin_distr = "adaptive", potential_name = "plummer")
# Out:
# optimal parameters for plummer with mass 161.47893455855902 GsolMass, lengthscale: 20.457859970203497 kpc, and other parameters: []
# RMSE of plummer fit: 0.12481661428809532
# RSQUARED of plummer fit: 0.9556349472835096

# %%
plotpotentialdensityfit(nr_bins = 100, bin_distr = "adaptive", potential_name = "dehnenspherical")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 plotpotentialdensityfit(nr_bins = 100, bin_distr = "adaptive", potential_name = "dehnenspherical")
#
# Cell In[33], line 3, in plotpotentialdensityfit(nr_bins, bin_distr, potential_name, savefig, save_name)
#       1 def plotpotentialdensityfit(nr_bins = 40, bin_distr = "adaptive", potential_name = "doublepowerlaw", savefig=False, save_name="Density_fit"):
#       2     bin_radius, bin_density, bin_poisson_error, bin_std = getdensityprofile(nr_bins=nr_bins, bin_distr=bin_distr)
# ----> 3     fit_parameters = getbestfit(nr_bins=nr_bins, bin_distr=bin_distr, potential_name=potential_name)
#       4     inputislog = False
#       6     fit_density = (calcpotentialdensity(bin_radius.value, potential_name, inputislog, *fit_parameters)) * units.Msun / (units.kpc**3)
#
# Cell In[32], line 37, in getbestfit(nr_bins, bin_distr, potential_name)
#      34     return calcpotentialdensity(r_log, potential_name, inputislog, *fit_params)
#      36 #loglog fit
# ---> 37 popt, pcov = curve_fit(model_for_fit, bin_radius_log, bin_density_log, p0=params)
#      39 params = list(popt)
#      40 print("optimal parameters for " + potential_name + " with mass " + str(total_mass.to("GsolMass")) + ", lengthscale: " + str(params[0]*units.kpc) + ", and other parameters: " + str(params[1:]))
#
# File ~\anaconda3\envs\tana2025\Lib\site-packages\scipy\optimize\_minpack_py.py:1021, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#    1018 if ydata.size != 1 and n > ydata.size:
#    1019     raise TypeError(f"The number of func parameters={n} must not"
#    1020                     f" exceed the number of data points={ydata.size}")
# -> 1021 res = leastsq(func, p0, Dfun=jac, full_output=1, **kwargs)
#    1022 popt, pcov, infodict, errmsg, ier = res
#    1023 ysize = len(infodict['fvec'])
#
# File ~\anaconda3\envs\tana2025\Lib\site-packages\scipy\optimize\_minpack_py.py:439, in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     437     if maxfev == 0:
#     438         maxfev = 200*(n + 1)
# --> 439     retval = _minpack._lmdif(func, x0, args, full_output, ftol, xtol,
#     440                              gtol, maxfev, epsfcn, factor, diag)
#     441 else:
#     442     if col_deriv:
#
# File ~\anaconda3\envs\tana2025\Lib\site-packages\scipy\optimize\_minpack_py.py:516, in _lightweight_memoizer.<locals>._memoized_func(params)
#     514 def _memoized_func(params):
#     515     if _memoized_func.skip_lookup:
# --> 516         return f(params)
#     518     if np.all(_memoized_func.last_params == params):
#     519         return _memoized_func.last_val
#
# File ~\anaconda3\envs\tana2025\Lib\site-packages\scipy\optimize\_minpack_py.py:540, in _wrap_func.<locals>.func_wrapped(params)
#     539 def func_wrapped(params):
# --> 540     return func(xdata, *params) - ydata
#
# Cell In[32], line 34, in getbestfit.<locals>.model_for_fit(r_log, *fit_params)
#      33 def model_for_fit(r_log, *fit_params):
# ---> 34     return calcpotentialdensity(r_log, potential_name, inputislog, *fit_params)
#
# Cell In[30], line 23, in calcpotentialdensity(bin_radius, potential_name, inputislog, *params)
#      21     potential = PlummerPotential(amp=mscale, b=lscale)
#      22 elif (potential_name == "dehnenspherical"):
# ---> 23     potential = DehnenSphericalPotential(amp=mscale, a=lscale, alpha=params[1])
#      24 elif (potential_name == "dehnencorespherical"):
#      25     potential = DehnenCoreSphericalPotential(amp=mscale, a=lscale)
#
# File ~\anaconda3\envs\tana2025\Lib\site-packages\galpy\potential\TwoPowerSphericalPotential.py:329, in DehnenSphericalPotential.__init__(self, amp, a, alpha, normalize, ro, vo)
#     306 """
#     307 Initialize a Dehnen Spherical Potential.
#     308
#    (...)    326 - Started - Starkman (UofT) - 2019-10-07
#     327 """
#     328 if (alpha < 0.0) or (alpha >= 3.0):
# --> 329     raise OSError("DehnenSphericalPotential requires 0 <= alpha < 3")
#     330 # instantiate
#     331 TwoPowerSphericalPotential.__init__(
#     332     self, amp=amp, a=a, alpha=alpha, beta=4, normalize=normalize, ro=ro, vo=vo
#     333 )
#
# OSError: DehnenSphericalPotential requires 0 <= alpha < 3

# %%
plotpotentialdensityfit(nr_bins = 100, bin_distr = "adaptive", potential_name = "dehnencorespherical")
# Out:
# C:\Users\niels\AppData\Local\Temp\ipykernel_15096\743650313.py:41: RuntimeWarning: invalid value encountered in log10
#   return np.log10(density.value)
#
# C:\Users\niels\AppData\Local\Temp\ipykernel_15096\743650313.py:41: RuntimeWarning: invalid value encountered in log10
#   return np.log10(density.value)
#
# optimal parameters for dehnencorespherical with mass 161.47893455855902 GsolMass, lengthscale: 7.528758185294644 kpc, and other parameters: []
# RMSE of dehnencorespherical fit: 0.6196879432105876
# RSQUARED of dehnencorespherical fit: -0.09355920096836545

# %%
plotpotentialdensityfit(nr_bins = 100, bin_distr = "adaptive", potential_name = "jaffe")
# Out:
# optimal parameters for jaffe with mass 161.47893455855902 GsolMass, lengthscale: 29.991345403797368 kpc, and other parameters: []
# RMSE of jaffe fit: 0.2501358774334946
# RSQUARED of jaffe fit: 0.8218244198124295

# %%
#only performs well in well-probed lengthscale, as seen in lectures
plotpotentialdensityfit(nr_bins = 100, bin_distr = "adaptive", potential_name = "nfw")
# Out:
# optimal parameters for nfw with mass 161.47893455855902 GsolMass, lengthscale: 12.056016901158507 kpc, and other parameters: []
# RMSE of nfw fit: 0.032215207628049525
# RSQUARED of nfw fit: 0.9970445877067959

# %%
plotpotentialdensityfit(nr_bins = 100, bin_distr = "adaptive", potential_name = "powerspherical")
# Out:
# optimal parameters for powerspherical with mass 161.47893455855902 GsolMass, lengthscale: 3049.078770976823 kpc, and other parameters: [np.float64(2.2887175222466056)]
# RMSE of powerspherical fit: 0.042979905742819624
# RSQUARED of powerspherical fit: 0.9947394988067705
